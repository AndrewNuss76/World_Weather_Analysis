# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the time module.
import time

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
#add lats and lngs to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
            # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dc = city_weather["weather"][0]["description"]
            # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                              "Country": city_country,
                              "Lat": city_lat,
                              "Lng": city_lng,
                              "Max Temp": city_max_temp,
                              "Humidity": city_humidity,
                              "Cloudiness": city_clouds,
                              "Wind Speed": city_wind,
                              "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | coahuayana
# Processing Record 2 of Set 1 | lompoc
# Processing Record 3 of Set 1 | dulce nombre de culmi
# Processing Record 4 of Set 1 | puerto escondido
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | lovozero
# Processing Record 10 of Set 1 | vung tau
# Processing Record 11 of Set 1 | ihosy
# Processing Record 12 of Set 1 | pinawa
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | geraldton
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | otavi
# Processing Record 18 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 1 | naze
# Processing Record 20 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | hobyo
# Processing Record 23 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 24 of Set 1 | alyangula
# Processing Record 25 of Set 1 | zyryanka
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | kodiak
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | gasa
# Processing Record 30 of Set 1 | shingu
# Processing Record 31 of Set 1 | talnakh
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | saskylakh
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | pangnirtung
# Processing Record 38 of Set 1 | vostok
# Processing Record 39 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 1 | jega
# Processing Record 41 of Set 1 | mahon
# Processing Record 42 of Set 1 | leninskoye
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | rognan
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | vestmanna
# Processing Record 49 of Set 1 | birobidzhan
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | saint-joseph
# Processing Record 3 of Set 2 | mahebourg
# Processing Record 4 of Set 2 | saint-pierre
# Processing Record 5 of Set 2 | nicoya
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | yeppoon
# Processing Record 8 of Set 2 | araceli
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | victoria
# Processing Record 11 of Set 2 | kaitangata
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | qeshm
# Processing Record 14 of Set 2 | udachnyy
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | klaksvik
# Processing Record 17 of Set 2 | thinadhoo
# Processing Record 18 of Set 2 | kavieng
# Processing Record 19 of Set 2 | pak phanang
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 2 | berdigestyakh
# Processing Record 24 of Set 2 | kankon
# Processing Record 25 of Set 2 | bajil
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | barka kana
# Processing Record 28 of Set 2 | santa ana
# Processing Record 29 of Set 2 | plettenberg bay
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | busselton
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 2 | togur
# Processing Record 36 of Set 2 | rikitea
# Processing Record 37 of Set 2 | barrow
# Processing Record 38 of Set 2 | tutoia
# Processing Record 39 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 2 | atuona
# Processing Record 41 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | viedma
# Processing Record 44 of Set 2 | dunedin
# Processing Record 45 of Set 2 | exu
# Processing Record 46 of Set 2 | bacolod
# Processing Record 47 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 2 | jacareacanga
# Processing Record 49 of Set 2 | clyde river
# Processing Record 50 of Set 2 | coihaique
# Processing Record 1 of Set 3 | hofn
# Processing Record 2 of Set 3 | marivan
# Processing Record 3 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 3 | acapulco
# Processing Record 5 of Set 3 | chicama
# Processing Record 6 of Set 3 | srednekolymsk
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | talaya
# Processing Record 9 of Set 3 | raton
# Processing Record 10 of Set 3 | anadyr
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | codrington
# Processing Record 13 of Set 3 | carnarvon
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | ahipara
# Processing Record 16 of Set 3 | hanko
# Processing Record 17 of Set 3 | aklavik
# Processing Record 18 of Set 3 | iisalmi
# Processing Record 19 of Set 3 | bethel
# Processing Record 20 of Set 3 | te anau
# Processing Record 21 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 22 of Set 3 | zhigansk
# Processing Record 23 of Set 3 | lishui
# Processing Record 24 of Set 3 | bure
# Processing Record 25 of Set 3 | odweyne
# Processing Record 26 of Set 3 | areka
# Processing Record 27 of Set 3 | mbekenyera
# Processing Record 28 of Set 3 | umm kaddadah
# Processing Record 29 of Set 3 | itoman
# Processing Record 30 of Set 3 | fortuna
# Processing Record 31 of Set 3 | ostersund
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | bathsheba
# Processing Record 34 of Set 3 | chabahar
# Processing Record 35 of Set 3 | tezu
# Processing Record 36 of Set 3 | buloh kasap
# Processing Record 37 of Set 3 | tarko-sale
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | razole
# Processing Record 40 of Set 3 | guerrero negro
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | chirala
# Processing Record 43 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | campbell river
# Processing Record 46 of Set 3 | alta floresta
# Processing Record 47 of Set 3 | hasaki
# Processing Record 48 of Set 3 | coruripe
# Processing Record 49 of Set 3 | shache
# Processing Record 50 of Set 3 | fairbanks
# Processing Record 1 of Set 4 | khatanga
# Processing Record 2 of Set 4 | susanville
# Processing Record 3 of Set 4 | sakakah
# Processing Record 4 of Set 4 | agua dulce
# Processing Record 5 of Set 4 | corrales
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | celestun
# Processing Record 8 of Set 4 | marawi
# Processing Record 9 of Set 4 | bambous virieux
# Processing Record 10 of Set 4 | chara
# Processing Record 11 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 12 of Set 4 | kruisfontein
# Processing Record 13 of Set 4 | idenao
# Processing Record 14 of Set 4 | east london
# Processing Record 15 of Set 4 | taltal
# Processing Record 16 of Set 4 | torbay
# Processing Record 17 of Set 4 | cap malheureux
# Processing Record 18 of Set 4 | ola
# Processing Record 19 of Set 4 | dandong
# Processing Record 20 of Set 4 | new norfolk
# Processing Record 21 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | gumdag
# Processing Record 24 of Set 4 | paita
# Processing Record 25 of Set 4 | kachug
# Processing Record 26 of Set 4 | dubbo
# Processing Record 27 of Set 4 | gillette
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | erenhot
# Processing Record 30 of Set 4 | kutum
# Processing Record 31 of Set 4 | paamiut
# Processing Record 32 of Set 4 | yulara
# Processing Record 33 of Set 4 | bantou
# Processing Record 34 of Set 4 | padang
# Processing Record 35 of Set 4 | ye
# City not found. Skipping...
# Processing Record 36 of Set 4 | georgiyevka
# Processing Record 37 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 4 | povenets
# Processing Record 39 of Set 4 | nome
# Processing Record 40 of Set 4 | busko-zdroj
# Processing Record 41 of Set 4 | nikolskoye
# Processing Record 42 of Set 4 | haines junction
# Processing Record 43 of Set 4 | vila velha
# Processing Record 44 of Set 4 | aylmer
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | kushmurun
# Processing Record 47 of Set 4 | deputatskiy
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 4 | coolum beach
# Processing Record 50 of Set 4 | riyadh
# Processing Record 1 of Set 5 | kupang
# Processing Record 2 of Set 5 | kapit
# Processing Record 3 of Set 5 | novorzhev
# Processing Record 4 of Set 5 | den helder
# Processing Record 5 of Set 5 | saint george
# Processing Record 6 of Set 5 | vao
# Processing Record 7 of Set 5 | nurota
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | payo
# Processing Record 10 of Set 5 | bredasdorp
# Processing Record 11 of Set 5 | san francisco
# Processing Record 12 of Set 5 | kansanshi
# Processing Record 13 of Set 5 | mar del plata
# Processing Record 14 of Set 5 | port hedland
# Processing Record 15 of Set 5 | novoagansk
# Processing Record 16 of Set 5 | samarai
# Processing Record 17 of Set 5 | mount isa
# Processing Record 18 of Set 5 | leh
# Processing Record 19 of Set 5 | pecos
# Processing Record 20 of Set 5 | sur
# Processing Record 21 of Set 5 | sinnamary
# Processing Record 22 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 5 | souillac
# Processing Record 24 of Set 5 | sorland
# Processing Record 25 of Set 5 | pevek
# Processing Record 26 of Set 5 | georgetown
# Processing Record 27 of Set 5 | tiarei
# Processing Record 28 of Set 5 | jamestown
# Processing Record 29 of Set 5 | cherskiy
# Processing Record 30 of Set 5 | norman wells
# Processing Record 31 of Set 5 | olafsvik
# Processing Record 32 of Set 5 | butaritari
# Processing Record 33 of Set 5 | tumaco
# Processing Record 34 of Set 5 | urumqi
# Processing Record 35 of Set 5 | kununurra
# Processing Record 36 of Set 5 | saint-francois
# Processing Record 37 of Set 5 | carutapera
# Processing Record 38 of Set 5 | atar
# Processing Record 39 of Set 5 | basco
# Processing Record 40 of Set 5 | maldonado
# Processing Record 41 of Set 5 | sambava
# Processing Record 42 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 5 | touros
# Processing Record 44 of Set 5 | dikson
# Processing Record 45 of Set 5 | lagoa
# Processing Record 46 of Set 5 | ulladulla
# Processing Record 47 of Set 5 | klyuchi
# Processing Record 48 of Set 5 | beringovskiy
# Processing Record 49 of Set 5 | hammerfest
# Processing Record 50 of Set 5 | staunton
# Processing Record 1 of Set 6 | iskandar
# Processing Record 2 of Set 6 | chuy
# Processing Record 3 of Set 6 | skjervoy
# Processing Record 4 of Set 6 | lorengau
# Processing Record 5 of Set 6 | rawson
# Processing Record 6 of Set 6 | sao filipe
# Processing Record 7 of Set 6 | nizwa
# Processing Record 8 of Set 6 | hambantota
# Processing Record 9 of Set 6 | mount gambier
# Processing Record 10 of Set 6 | nioro
# Processing Record 11 of Set 6 | zatyshshya
# Processing Record 12 of Set 6 | avanigadda
# Processing Record 13 of Set 6 | porto novo
# Processing Record 14 of Set 6 | agucadoura
# Processing Record 15 of Set 6 | kamaishi
# Processing Record 16 of Set 6 | mogadouro
# Processing Record 17 of Set 6 | meulaboh
# Processing Record 18 of Set 6 | avera
# Processing Record 19 of Set 6 | lavrentiya
# Processing Record 20 of Set 6 | diglur
# Processing Record 21 of Set 6 | notodden
# Processing Record 22 of Set 6 | road town
# Processing Record 23 of Set 6 | nanakuli
# Processing Record 24 of Set 6 | richards bay
# Processing Record 25 of Set 6 | asau
# Processing Record 26 of Set 6 | yashan
# Processing Record 27 of Set 6 | joetsu
# Processing Record 28 of Set 6 | severo-kurilsk
# Processing Record 29 of Set 6 | umm lajj
# Processing Record 30 of Set 6 | moose factory
# Processing Record 31 of Set 6 | chifeng
# Processing Record 32 of Set 6 | dhidhdhoo
# Processing Record 33 of Set 6 | wanning
# Processing Record 34 of Set 6 | xiongyue
# Processing Record 35 of Set 6 | puerto carreno
# Processing Record 36 of Set 6 | rio gallegos
# Processing Record 37 of Set 6 | nizhniy kuranakh
# Processing Record 38 of Set 6 | sitka
# Processing Record 39 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 6 | acarau
# Processing Record 41 of Set 6 | pisco
# Processing Record 42 of Set 6 | mechetinskaya
# Processing Record 43 of Set 6 | langsa
# Processing Record 44 of Set 6 | ha giang
# Processing Record 45 of Set 6 | airai
# Processing Record 46 of Set 6 | puri
# Processing Record 47 of Set 6 | zapolyarnyy
# Processing Record 48 of Set 6 | pedernales
# Processing Record 49 of Set 6 | aswan
# Processing Record 50 of Set 6 | san quintin
# Processing Record 1 of Set 7 | bubaque
# Processing Record 2 of Set 7 | dimbokro
# Processing Record 3 of Set 7 | itaituba
# Processing Record 4 of Set 7 | college
# Processing Record 5 of Set 7 | tara
# Processing Record 6 of Set 7 | komsomolskiy
# Processing Record 7 of Set 7 | yairipok
# Processing Record 8 of Set 7 | los algarrobos
# Processing Record 9 of Set 7 | poum
# Processing Record 10 of Set 7 | mehamn
# Processing Record 11 of Set 7 | muros
# Processing Record 12 of Set 7 | mweka
# Processing Record 13 of Set 7 | mendi
# Processing Record 14 of Set 7 | valparaiso
# Processing Record 15 of Set 7 | praia da vitoria
# Processing Record 16 of Set 7 | athens
# Processing Record 17 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 7 | saquena
# Processing Record 19 of Set 7 | karratha
# Processing Record 20 of Set 7 | le moule
# Processing Record 21 of Set 7 | bengkulu
# Processing Record 22 of Set 7 | koumac
# Processing Record 23 of Set 7 | marsa matruh
# Processing Record 24 of Set 7 | hualmay
# Processing Record 25 of Set 7 | kawalu
# Processing Record 26 of Set 7 | panuco
# Processing Record 27 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 7 | presidencia roque saenz pena
# Processing Record 29 of Set 7 | perth
# Processing Record 30 of Set 7 | port lincoln
# Processing Record 31 of Set 7 | tavrichanka
# Processing Record 32 of Set 7 | gornopravdinsk
# Processing Record 33 of Set 7 | sturgis
# Processing Record 34 of Set 7 | redcliffe
# Processing Record 35 of Set 7 | charters towers
# Processing Record 36 of Set 7 | northam
# Processing Record 37 of Set 7 | rantoul
# Processing Record 38 of Set 7 | liverpool
# Processing Record 39 of Set 7 | arlit
# Processing Record 40 of Set 7 | altay
# Processing Record 41 of Set 7 | huarmey
# Processing Record 42 of Set 7 | deyang
# Processing Record 43 of Set 7 | simao
# Processing Record 44 of Set 7 | guider
# Processing Record 45 of Set 7 | ketchikan
# Processing Record 46 of Set 7 | dongsheng
# Processing Record 47 of Set 7 | bull savanna
# Processing Record 48 of Set 7 | pyu
# Processing Record 49 of Set 7 | morki
# Processing Record 50 of Set 7 | eyl
# Processing Record 1 of Set 8 | portland
# Processing Record 2 of Set 8 | pervomayskiy
# Processing Record 3 of Set 8 | honiara
# Processing Record 4 of Set 8 | isangel
# Processing Record 5 of Set 8 | santa isabel do rio negro
# Processing Record 6 of Set 8 | ambatolampy
# Processing Record 7 of Set 8 | palmer
# Processing Record 8 of Set 8 | tazovskiy
# Processing Record 9 of Set 8 | camacha
# Processing Record 10 of Set 8 | sioux lookout
# Processing Record 11 of Set 8 | ancud
# Processing Record 12 of Set 8 | aksu
# Processing Record 13 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 8 | yerbogachen
# Processing Record 15 of Set 8 | sobolevo
# Processing Record 16 of Set 8 | loandjili
# Processing Record 17 of Set 8 | bijar
# Processing Record 18 of Set 8 | le port
# Processing Record 19 of Set 8 | savannah bight
# Processing Record 20 of Set 8 | ingham
# Processing Record 21 of Set 8 | gimbi
# Processing Record 22 of Set 8 | cayenne
# Processing Record 23 of Set 8 | penzance
# Processing Record 24 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 8 | muli
# Processing Record 26 of Set 8 | san vicente
# Processing Record 27 of Set 8 | sakaiminato
# Processing Record 28 of Set 8 | dalbandin
# Processing Record 29 of Set 8 | musafirkhana
# Processing Record 30 of Set 8 | namibe
# Processing Record 31 of Set 8 | nanortalik
# Processing Record 32 of Set 8 | marv dasht
# City not found. Skipping...
# Processing Record 33 of Set 8 | stykkisholmur
# Processing Record 34 of Set 8 | rey bouba
# Processing Record 35 of Set 8 | tamiahua
# Processing Record 36 of Set 8 | amapa
# Processing Record 37 of Set 8 | kavaratti
# Processing Record 38 of Set 8 | strezhevoy
# Processing Record 39 of Set 8 | muhos
# Processing Record 40 of Set 8 | grand-santi
# Processing Record 41 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 8 | tsurib
# Processing Record 43 of Set 8 | dingle
# Processing Record 44 of Set 8 | nishihara
# Processing Record 45 of Set 8 | albacete
# Processing Record 46 of Set 8 | nyrob
# Processing Record 47 of Set 8 | sarangani
# Processing Record 48 of Set 8 | walvis bay
# Processing Record 49 of Set 8 | belmonte
# Processing Record 50 of Set 8 | tianpeng
# Processing Record 1 of Set 9 | jinchang
# Processing Record 2 of Set 9 | vilhena
# Processing Record 3 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 4 of Set 9 | kodinsk
# Processing Record 5 of Set 9 | margate
# Processing Record 6 of Set 9 | nieuw amsterdam
# Processing Record 7 of Set 9 | jardim
# Processing Record 8 of Set 9 | bay city
# Processing Record 9 of Set 9 | makakilo city
# Processing Record 10 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 11 of Set 9 | kirakira
# Processing Record 12 of Set 9 | jalu
# Processing Record 13 of Set 9 | ojinaga
# Processing Record 14 of Set 9 | bam
# Processing Record 15 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 9 | vila franca do campo
# Processing Record 17 of Set 9 | groningen
# Processing Record 18 of Set 9 | bonthe
# Processing Record 19 of Set 9 | sechura
# Processing Record 20 of Set 9 | gao
# Processing Record 21 of Set 9 | kuytun
# Processing Record 22 of Set 9 | sandwick
# Processing Record 23 of Set 9 | san andres
# Processing Record 24 of Set 9 | moura
# Processing Record 25 of Set 9 | oka
# Processing Record 26 of Set 9 | sinjar
# Processing Record 27 of Set 9 | nichinan
# Processing Record 28 of Set 9 | black river
# Processing Record 29 of Set 9 | harrisburg
# Processing Record 30 of Set 9 | san jose
# Processing Record 31 of Set 9 | calvinia
# Processing Record 32 of Set 9 | lillooet
# Processing Record 33 of Set 9 | kishtwar
# Processing Record 34 of Set 9 | ixtapa
# Processing Record 35 of Set 9 | cortes
# Processing Record 36 of Set 9 | capela do alto
# Processing Record 37 of Set 9 | sehithwa
# Processing Record 38 of Set 9 | husavik
# Processing Record 39 of Set 9 | kemijarvi
# Processing Record 40 of Set 9 | dong hoi
# Processing Record 41 of Set 9 | madang
# Processing Record 42 of Set 9 | bulungu
# Processing Record 43 of Set 9 | key west
# Processing Record 44 of Set 9 | teguldet
# Processing Record 45 of Set 9 | bartlesville
# Processing Record 46 of Set 9 | digha
# Processing Record 47 of Set 9 | micheweni
# Processing Record 48 of Set 9 | bamiantong
# Processing Record 49 of Set 9 | foso
# Processing Record 50 of Set 9 | fethiye
# Processing Record 1 of Set 10 | doha
# Processing Record 2 of Set 10 | kichera
# Processing Record 3 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 10 | araouane
# Processing Record 5 of Set 10 | lazaro cardenas
# Processing Record 6 of Set 10 | west wendover
# Processing Record 7 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 10 | tingo maria
# Processing Record 9 of Set 10 | hami
# Processing Record 10 of Set 10 | arica
# Processing Record 11 of Set 10 | carora
# Processing Record 12 of Set 10 | lahij
# Processing Record 13 of Set 10 | mithi
# Processing Record 14 of Set 10 | waingapu
# Processing Record 15 of Set 10 | narsaq
# Processing Record 16 of Set 10 | islampur
# Processing Record 17 of Set 10 | kuusamo
# Processing Record 18 of Set 10 | broome
# Processing Record 19 of Set 10 | gat
# Processing Record 20 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 10 | bara
# Processing Record 22 of Set 10 | dulce grande
# Processing Record 23 of Set 10 | mubi
# Processing Record 24 of Set 10 | tengzhou
# Processing Record 25 of Set 10 | san rafael
# Processing Record 26 of Set 10 | nisia floresta
# Processing Record 27 of Set 10 | murgab
# Processing Record 28 of Set 10 | burica
# City not found. Skipping...
# Processing Record 29 of Set 10 | madruga
# Processing Record 30 of Set 10 | champerico
# Processing Record 31 of Set 10 | norden
# Processing Record 32 of Set 10 | formosa do rio preto
# Processing Record 33 of Set 10 | buin
# Processing Record 34 of Set 10 | roald
# Processing Record 35 of Set 10 | bay roberts
# Processing Record 36 of Set 10 | sapa
# Processing Record 37 of Set 10 | kodinar
# Processing Record 38 of Set 10 | timmins
# Processing Record 39 of Set 10 | puerto madryn
# Processing Record 40 of Set 10 | nemuro
# Processing Record 41 of Set 10 | do rud
# City not found. Skipping...
# Processing Record 42 of Set 10 | palora
# Processing Record 43 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 10 | kayerkan
# Processing Record 45 of Set 10 | serebryanyy bor
# Processing Record 46 of Set 10 | bhabua
# Processing Record 47 of Set 10 | rantauprapat
# Processing Record 48 of Set 10 | kenai
# Processing Record 49 of Set 10 | salinopolis
# Processing Record 50 of Set 10 | flin flon
# Processing Record 1 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 2 of Set 11 | takaungu
# Processing Record 3 of Set 11 | mitsamiouli
# Processing Record 4 of Set 11 | port moresby
# Processing Record 5 of Set 11 | wajir
# Processing Record 6 of Set 11 | ruidoso
# Processing Record 7 of Set 11 | necochea
# Processing Record 8 of Set 11 | cavalcante
# Processing Record 9 of Set 11 | tongliao
# Processing Record 10 of Set 11 | etchoropo
# Processing Record 11 of Set 11 | bandarbeyla
# Processing Record 12 of Set 11 | vredendal
# Processing Record 13 of Set 11 | ulaangom
# Processing Record 14 of Set 11 | los llanos de aridane
# Processing Record 15 of Set 11 | griffith
# Processing Record 16 of Set 11 | nikel
# Processing Record 17 of Set 11 | andijon
# Processing Record 18 of Set 11 | samarinda
# Processing Record 19 of Set 11 | north bend
# Processing Record 20 of Set 11 | manggar
# Processing Record 21 of Set 11 | lamu
# Processing Record 22 of Set 11 | huambo
# Processing Record 23 of Set 11 | nunoa
# Processing Record 24 of Set 11 | panzhihua
# Processing Record 25 of Set 11 | mahibadhoo
# Processing Record 26 of Set 11 | helong
# Processing Record 27 of Set 11 | faanui
# Processing Record 28 of Set 11 | andenes
# Processing Record 29 of Set 11 | baghdad
# Processing Record 30 of Set 11 | lasa
# Processing Record 31 of Set 11 | port hawkesbury
# Processing Record 32 of Set 11 | lalmohan
# Processing Record 33 of Set 11 | orvieto
# Processing Record 34 of Set 11 | fort-shevchenko
# Processing Record 35 of Set 11 | caceres
# Processing Record 36 of Set 11 | cayeli
# Processing Record 37 of Set 11 | cody
# Processing Record 38 of Set 11 | peleduy
# Processing Record 39 of Set 11 | rognedino
# Processing Record 40 of Set 11 | miri
# Processing Record 41 of Set 11 | roebourne
# Processing Record 42 of Set 11 | sogdiondon
# City not found. Skipping...
# Processing Record 43 of Set 11 | port-gentil
# Processing Record 44 of Set 11 | takhtamygda
# Processing Record 45 of Set 11 | fez
# Processing Record 46 of Set 11 | nuuk
# Processing Record 47 of Set 11 | yarensk
# Processing Record 48 of Set 11 | vriezenveen
# Processing Record 49 of Set 11 | marrakesh
# Processing Record 50 of Set 11 | berlevag
# Processing Record 1 of Set 12 | khudumelapye
# Processing Record 2 of Set 12 | athabasca
# Processing Record 3 of Set 12 | arrecife
# Processing Record 4 of Set 12 | reconquista
# Processing Record 5 of Set 12 | trairi
# Processing Record 6 of Set 12 | dunda
# Processing Record 7 of Set 12 | plouzane
# Processing Record 8 of Set 12 | denpasar
# Processing Record 9 of Set 12 | arya
# Processing Record 10 of Set 12 | kedrovyy
# Processing Record 11 of Set 12 | puerto penasco
# Processing Record 12 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 13 of Set 12 | boende
# Processing Record 14 of Set 12 | deder
# Processing Record 15 of Set 12 | aksarka
# Processing Record 16 of Set 12 | el fuerte
# Processing Record 17 of Set 12 | sindhnur
# Processing Record 18 of Set 12 | fare
# Processing Record 19 of Set 12 | ribeira grande
# Processing Record 20 of Set 12 | izhma
# Processing Record 21 of Set 12 | spornoye
# Processing Record 22 of Set 12 | ko samui
# Processing Record 23 of Set 12 | kalmunai
# Processing Record 24 of Set 12 | tabou
# Processing Record 25 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 26 of Set 12 | vorotynets
# Processing Record 27 of Set 12 | longyearbyen
# Processing Record 28 of Set 12 | vanimo
# Processing Record 29 of Set 12 | bougouni
# Processing Record 30 of Set 12 | centralia
# Processing Record 31 of Set 12 | hamilton
# Processing Record 32 of Set 12 | boromo
# Processing Record 33 of Set 12 | point pedro
# Processing Record 34 of Set 12 | russell
# Processing Record 35 of Set 12 | luderitz
# Processing Record 36 of Set 12 | comodoro rivadavia
# Processing Record 37 of Set 12 | santa maria
# Processing Record 38 of Set 12 | nara
# Processing Record 39 of Set 12 | tigzirt
# Processing Record 40 of Set 12 | chernyshevskiy
# Processing Record 41 of Set 12 | navapur
# City not found. Skipping...
# Processing Record 42 of Set 12 | djibo
# Processing Record 43 of Set 12 | blacklick estates
# Processing Record 44 of Set 12 | iquique
# Processing Record 45 of Set 12 | kilindoni
# Processing Record 46 of Set 12 | half moon bay
# Processing Record 47 of Set 12 | irece
# Processing Record 48 of Set 12 | mogadishu
# Processing Record 49 of Set 12 | phangnga
# Processing Record 50 of Set 12 | buraydah
# Processing Record 1 of Set 13 | aljezur
# Processing Record 2 of Set 13 | trapani
# Processing Record 3 of Set 13 | pangody
# Processing Record 4 of Set 13 | yenagoa
# Processing Record 5 of Set 13 | lisakovsk
# Processing Record 6 of Set 13 | toora-khem
# Processing Record 7 of Set 13 | olot
# Processing Record 8 of Set 13 | kangaba
# Processing Record 9 of Set 13 | shahreza
# Processing Record 10 of Set 13 | quatre cocos
# Processing Record 11 of Set 13 | port hardy
# Processing Record 12 of Set 13 | antalaha
# Processing Record 13 of Set 13 | owando
# Processing Record 14 of Set 13 | bilibino
# Processing Record 15 of Set 13 | glenwood springs
# Processing Record 16 of Set 13 | khash
# Processing Record 17 of Set 13 | mitchell
# Processing Record 18 of Set 13 | ostrovnoy
# Processing Record 19 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 20 of Set 13 | garowe
# Processing Record 21 of Set 13 | lebedinyy
# Processing Record 22 of Set 13 | jibuti
# Processing Record 23 of Set 13 | sortland
# Processing Record 24 of Set 13 | rio grande
# Processing Record 25 of Set 13 | onega
# Processing Record 26 of Set 13 | manesti
# Processing Record 27 of Set 13 | gushikawa
# Processing Record 28 of Set 13 | zhangye
# Processing Record 29 of Set 13 | san-pedro
# Processing Record 30 of Set 13 | las vegas
# Processing Record 31 of Set 13 | vanderhoof
# Processing Record 32 of Set 13 | pacific grove
# Processing Record 33 of Set 13 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 13 | tilichiki
# Processing Record 35 of Set 13 | red bluff
# Processing Record 36 of Set 13 | kuandian
# Processing Record 37 of Set 13 | tabarqah
# City not found. Skipping...
# Processing Record 38 of Set 13 | winton
# Processing Record 39 of Set 13 | oranjemund
# Processing Record 40 of Set 13 | tura
# Processing Record 41 of Set 13 | vestmannaeyjar
# Processing Record 42 of Set 13 | girvan
# Processing Record 43 of Set 13 | invermere
# Processing Record 44 of Set 13 | shelburne
# Processing Record 45 of Set 13 | kon tum
# Processing Record 46 of Set 13 | aiquile
# Processing Record 47 of Set 13 | bilma
# Processing Record 48 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 49 of Set 13 | sangar
# Processing Record 50 of Set 13 | maceo
# Processing Record 1 of Set 14 | perigueux
# Processing Record 2 of Set 14 | waipawa
# Processing Record 3 of Set 14 | bereda
# Processing Record 4 of Set 14 | xiamen
# Processing Record 5 of Set 14 | cap-aux-meules
# Processing Record 6 of Set 14 | bulgan
# Processing Record 7 of Set 14 | ningxiang
# Processing Record 8 of Set 14 | gewane
# Processing Record 9 of Set 14 | sao joao dos patos
# Processing Record 10 of Set 14 | cauquenes
# Processing Record 11 of Set 14 | hendrina
# Processing Record 12 of Set 14 | humaita
# Processing Record 13 of Set 14 | cabreuva
# Processing Record 14 of Set 14 | ternate
# Processing Record 15 of Set 14 | suluq
# Processing Record 16 of Set 14 | hvolsvollur
# Processing Record 17 of Set 14 | rundu
# Processing Record 18 of Set 14 | zawiercie
# Processing Record 19 of Set 14 | tabuk
# Processing Record 20 of Set 14 | mbabane
# Processing Record 21 of Set 14 | soe
# Processing Record 22 of Set 14 | fermoy
# Processing Record 23 of Set 14 | ahuimanu
# Processing Record 24 of Set 14 | cedarburg
# Processing Record 25 of Set 14 | yuanping
# Processing Record 26 of Set 14 | vazante
# Processing Record 27 of Set 14 | luganville
# Processing Record 28 of Set 14 | iqaluit
# Processing Record 29 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 30 of Set 14 | coria
# Processing Record 31 of Set 14 | bafq
# Processing Record 32 of Set 14 | aykhal
# Processing Record 33 of Set 14 | laurel
# Processing Record 34 of Set 14 | tuatapere
# Processing Record 35 of Set 14 | grenfell
# Processing Record 36 of Set 14 | high level
# Processing Record 37 of Set 14 | biltine
# Processing Record 38 of Set 14 | kenora
# Processing Record 39 of Set 14 | sandim
# Processing Record 40 of Set 14 | chimoio
# Processing Record 41 of Set 14 | tual
# Processing Record 42 of Set 14 | frontera
# Processing Record 43 of Set 14 | great yarmouth
# Processing Record 44 of Set 14 | mackay
# Processing Record 45 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 46 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 14 | beipiao
# Processing Record 48 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 49 of Set 14 | telsiai
# Processing Record 50 of Set 14 | nokaneng
# Processing Record 1 of Set 15 | lucapa
# Processing Record 2 of Set 15 | glubokoe
# City not found. Skipping...
# Processing Record 3 of Set 15 | zaraza
# Processing Record 4 of Set 15 | raymondville
# Processing Record 5 of Set 15 | saquarema
# Processing Record 6 of Set 15 | kaa-khem
# Processing Record 7 of Set 15 | la crosse
# Processing Record 8 of Set 15 | buxtehude
# Processing Record 9 of Set 15 | thunder bay
# Processing Record 10 of Set 15 | nagua
# Processing Record 11 of Set 15 | xacmaz
# Processing Record 12 of Set 15 | ayan
# Processing Record 13 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 15 | rylsk
# Processing Record 15 of Set 15 | novonikolayevskiy
# Processing Record 16 of Set 15 | barroquinha
# Processing Record 17 of Set 15 | olinda
# Processing Record 18 of Set 15 | enshi
# Processing Record 19 of Set 15 | vangaindrano
# Processing Record 20 of Set 15 | ponta delgada
# Processing Record 21 of Set 15 | concepcion
# Processing Record 22 of Set 15 | svetlyy
# Processing Record 23 of Set 15 | killam
# Processing Record 24 of Set 15 | evensk
# Processing Record 25 of Set 15 | garden city
# Processing Record 26 of Set 15 | asayita
# City not found. Skipping...
# Processing Record 27 of Set 15 | huilong
# Processing Record 28 of Set 15 | cockburn town
# Processing Record 29 of Set 15 | hit
# Processing Record 30 of Set 15 | nabire
# Processing Record 31 of Set 15 | xining
# Processing Record 32 of Set 15 | bonavista
# Processing Record 33 of Set 15 | hvide sande
# Processing Record 34 of Set 15 | lapua
# Processing Record 35 of Set 15 | batagay-alyta
# Processing Record 36 of Set 15 | coquimbo
# Processing Record 37 of Set 15 | struthers
# Processing Record 38 of Set 15 | belozerskoye
# Processing Record 39 of Set 15 | ust-maya
# Processing Record 40 of Set 15 | gorontalo
# Processing Record 41 of Set 15 | polyarnyye zori
# Processing Record 42 of Set 15 | elliot
# Processing Record 43 of Set 15 | hervey bay
# Processing Record 44 of Set 15 | pimentel
# Processing Record 45 of Set 15 | ndola
# Processing Record 46 of Set 15 | arenal
# Processing Record 47 of Set 15 | san ramon
# Processing Record 48 of Set 15 | elko
# Processing Record 49 of Set 15 | michigan city
# Processing Record 50 of Set 15 | goderich
# Processing Record 1 of Set 16 | maniitsoq
# Processing Record 2 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 16 | baykit
# Processing Record 4 of Set 16 | nushki
# Processing Record 5 of Set 16 | ongandjera
# Processing Record 6 of Set 16 | borgo san dalmazzo
# Processing Record 7 of Set 16 | biak
# Processing Record 8 of Set 16 | ambilobe
# Processing Record 9 of Set 16 | constitucion
# Processing Record 10 of Set 16 | stromness
# Processing Record 11 of Set 16 | norton shores
# Processing Record 12 of Set 16 | okato
# Processing Record 13 of Set 16 | havre-saint-pierre
# Processing Record 14 of Set 16 | mozelos
# Processing Record 15 of Set 16 | josefina
# Processing Record 16 of Set 16 | byron bay
# Processing Record 17 of Set 16 | mackenzie
# Processing Record 18 of Set 16 | prince rupert
# Processing Record 19 of Set 16 | salamiyah
# Processing Record 20 of Set 16 | la ronge
# Processing Record 21 of Set 16 | oussouye
# Processing Record 22 of Set 16 | tecoanapa
# Processing Record 23 of Set 16 | diamantino
# Processing Record 24 of Set 16 | mayumba
# Processing Record 25 of Set 16 | jeremoabo
# Processing Record 26 of Set 16 | shintomi
# Processing Record 27 of Set 16 | moron
# Processing Record 28 of Set 16 | nosivka
# Processing Record 29 of Set 16 | neftcala
# Processing Record 30 of Set 16 | gamboma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                     City Country    Lat     Lng  Max Temp  Humidity  \
# 0             Coahuayana      MX  18.73 -103.68     89.10        50
# 1                 Lompoc      US  34.64 -120.46     55.40        66
# 2  Dulce Nombre De Culmi      HN  15.10  -85.53     86.00        74
# 3       Puerto Escondido      MX  15.85  -97.07     87.80        66
# 4         Saint-Philippe      RE -21.36   55.77     73.40        78
# 5                Mataura      NZ -46.19  168.86     50.00        92
# 6           Puerto Ayora      EC  -0.74  -90.35     77.00        73
# 7              Cape Town      ZA -33.93   18.42     60.01        67
# 8               Lovozero      RU  68.00   35.01     30.79        94
# 9               Vung Tau      VN  10.35  107.08     78.06        82
#
#    Cloudiness  Wind Speed Current Description
# 0          18        5.59          few clouds
# 1          75       19.46       broken clouds
# 2          75        1.12       broken clouds
# 3          40        5.82    scattered clouds
# 4           0        8.05           clear sky
# 5         100        2.04     overcast clouds
# 6          40       20.80    scattered clouds
# 7          75        8.05       broken clouds
# 8          94       21.39     overcast clouds
# 9         100        4.90     overcast clouds

# %%
# Create the output file (CSV).
data_output_csv = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(data_output_csv, index_label="City_ID")
